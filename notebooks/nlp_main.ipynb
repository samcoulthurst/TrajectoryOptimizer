# %%
from cr3bp.nlp import solve_transfer_optimization
x_opt, info = solve_transfer_optimization()
# Out:
# Initial guess from grid search: [3.96961565 3.02484418 0.07460938 0.72992717]
#   theta          = 3.969616 rad
#   delta_v        = 3.024844 (normalized) = 3.0990 km/s
#   delta_v_angle  = 0.074609 rad
#   tof            = 0.729927 (normalized) = 3.170 days
#
# ...
# OPTIMIZATION RESULTS
# ...
# Solver status: b'Maximum number of iterations exceeded (can be specified by an option).'
#
# Optimal decision variables:
#   theta          = 3.951267 rad
#   delta_v        = 3.035282 (normalized) = 3.1097 km/s
#   delta_v_angle  = 0.010944 rad
#   tof            = 0.633651 (normalized) = 2.752 days
#
# Total delta-v:
#   Normalized     = 3.094314
#   SI             = 3170.22 m/s
#   SI             = 3.1702 km/s
#
# Constraint satisfaction:
#   distance_rocket_lmo (normalized) = -1.270902e-04
#   distance_rocket_lmo (km)         = -48.8535
#
# Time of flight: 2.752 days
# ...
