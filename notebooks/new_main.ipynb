# %%
from cr3bp.nlp import solve_transfer_optimization
x_opt, info = solve_transfer_optimization()
# Out:
# Initial guess from grid search: [3.95789474 3.02631579 0.07222222 0.71052632]
#   theta          = 3.957895 rad
#   delta_v        = 3.026316 (normalized) = 3.1005 km/s
#   delta_v_angle  = 0.072222 rad
#   tof            = 0.710526 (normalized) = 3.085 days
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 2
#       1 from cr3bp.nlp import solve_transfer_optimization
# ----> 2 x_opt, info = solve_transfer_optimization()
#
# File ~\Documents\GitHub\TrajectoryOptimizer\cr3bp\nlp.py:179, in solve_transfer_optimization()
#     176 nlp.add_option('mu_strategy', 'adaptive')
#     178 ### Solve ######################################################
# --> 179 x_opt, info = nlp.solve(x0)
#     181 ### Results ####################################################
#     182 constraint_val, objective_val = evaluate(em, x_opt, leo_alt_m, lmo_alt_m)
#
# ...
