# %%
from cr3bp.nlp import solve_transfer_optimization
x_opt, info = solve_transfer_optimization()
# Out:
# Initial guess from grid search: [3.90820513 3.03578947 0.08684211 0.65615385]
#   theta          = 3.908205 rad
#   delta_v        = 3.035789 (normalized) = 3.1103 km/s
#   delta_v_angle  = 0.086842 rad
#   tof            = 0.656154 (normalized) = 2.849 days
#
# ...
# OPTIMIZATION RESULTS
# ...
# Solver status: b'Algorithm converged to a point of local infeasibility. Problem may be infeasible.'
#
# Optimal decision variables:
#   theta          = 4.500000 rad
#   delta_v        = 2.792510 (normalized) = 2.8610 km/s
#   delta_v_angle  = 0.200000 rad
#   tof            = 1.500000 (normalized) = 6.514 days
#
# Total delta-v:
#   Normalized     = 3.342852
#   SI             = 3424.85 m/s
#   SI             = 3.4248 km/s
#
# Constraint satisfaction:
#   distance_rocket_lmo (normalized) = 7.357765e-01
#   distance_rocket_lmo (km)         = 282832.5034
#
# Time of flight: 6.514 days
# ...
